# %%
import chart_studio.plotly as py

# %%
import pandas as pd
import numpy as np

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
print(__version__)
# Out:
# 5.1.0

# %%
import cufflinks as cf
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Get Data (Fake Data)

# %%
df = pd.DataFrame(np.random.randn(100, 4), columns=list('ABCD'))
df
# Out:
#            A         B         C         D
# 0  -1.526445  0.396094  0.407440 -2.503902
# 1   0.044974  0.471124  1.432560  1.032825
# 2   0.978840 -0.921865 -0.831785 -1.183567
# 3   1.270377 -0.242116 -0.713321 -1.186876
# 4  -1.318569 -1.040417  1.589942  0.984227
# ..       ...       ...       ...       ...
# 95 -0.949062 -0.481742 -0.170484  0.163566
# 96 -1.549986 -0.152059 -1.509739 -0.111406
# 97 -0.860243  0.034550 -0.876827  1.593046
# 98  0.063483 -1.067223  0.231823 -0.863610
# 99  0.765604  1.123523 -1.173444  0.116086
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -1.526445  0.396094  0.407440 -2.503902
# 1  0.044974  0.471124  1.432560  1.032825
# 2  0.978840 -0.921865 -0.831785 -1.183567
# 3  1.270377 -0.242116 -0.713321 -1.186876
# 4 -1.318569 -1.040417  1.589942  0.984227

# %%
df_1 = pd.DataFrame({"Category":['A', 'B', 'C'], "Values": [100, 30, 50]})

# %%
df_1
# Out:
#   Category  Values
# 0        A     100
# 1        B      30
# 2        C      50

# %% [markdown]
# # USING CUFFLINKS AND IPLOT()

# %%
df.iplot()
# Out:
# <div>                            <div id="ad892771-0e87-41e7-bb9c-5ca88096a838" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df_1.iplot()
# Out:
# <div>                            <div id="bd3591e9-ec7d-4d0a-9e59-ac5dce565be5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -1.526445  0.396094  0.407440 -2.503902
# 1  0.044974  0.471124  1.432560  1.032825
# 2  0.978840 -0.921865 -0.831785 -1.183567
# 3  1.270377 -0.242116 -0.713321 -1.186876
# 4 -1.318569 -1.040417  1.589942  0.984227

# %%
# scatter: 
df.iplot(kind='scatter', x='A', y='B', mode='markers', size=10)
# Out:
# <div>                            <div id="9d86900d-5812-499d-b220-f7ce8384f91d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df_1.head()
# Out:
#   Category  Values
# 0        A     100
# 1        B      30
# 2        C      50

# %%
df_1.iplot(kind='scatter', x='Category', y='Values', mode='markers', size=10)
# Out:
# <div>                            <div id="45c4ba43-d4b4-41c9-92c3-2f2b484d97bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# bar plots: https://plot.ly/python/bar-charts/

df_1.iplot(kind='bar', x='Category', y='Values')
# Out:
# <div>                            <div id="e82390af-9249-4776-88d9-eea5f283a0bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bar', x='A', y='B')
# Out:
# <div>                            <div id="7803b007-a900-4ec0-a352-3a037fac59b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#            A         B         C         D
# 0  -1.526445  0.396094  0.407440 -2.503902
# 1   0.044974  0.471124  1.432560  1.032825
# 2   0.978840 -0.921865 -0.831785 -1.183567
# 3   1.270377 -0.242116 -0.713321 -1.186876
# 4  -1.318569 -1.040417  1.589942  0.984227
# ..       ...       ...       ...       ...
# 95 -0.949062 -0.481742 -0.170484  0.163566
# 96 -1.549986 -0.152059 -1.509739 -0.111406
# 97 -0.860243  0.034550 -0.876827  1.593046
# 98  0.063483 -1.067223  0.231823 -0.863610
# 99  0.765604  1.123523 -1.173444  0.116086
#
# [100 rows x 4 columns]

# %%
df.count().iplot(kind='bar', color='darkred')
# Out:
# <div>                            <div id="1d51b44a-4b4c-4ad5-ac93-051463dafd1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df_1.count().iplot(kind='bar', color='darkred')
# Out:
# <div>                            <div id="4b73ac99-2190-434f-9005-ff7c1eb4ced7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#            A         B         C         D
# 0  -1.526445  0.396094  0.407440 -2.503902
# 1   0.044974  0.471124  1.432560  1.032825
# 2   0.978840 -0.921865 -0.831785 -1.183567
# 3   1.270377 -0.242116 -0.713321 -1.186876
# 4  -1.318569 -1.040417  1.589942  0.984227
# ..       ...       ...       ...       ...
# 95 -0.949062 -0.481742 -0.170484  0.163566
# 96 -1.549986 -0.152059 -1.509739 -0.111406
# 97 -0.860243  0.034550 -0.876827  1.593046
# 98  0.063483 -1.067223  0.231823 -0.863610
# 99  0.765604  1.123523 -1.173444  0.116086
#
# [100 rows x 4 columns]

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>                            <div id="86977fb1-1a83-4f33-a736-5db3e68e63d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>                            <div id="cdab3db4-7ef1-43d0-a4f4-b6a12a96a6a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({'x': [1, 2, 3, 4, 5], 'y': [10, 20, 30, 40, 50], 'z': [100, 200, 300, 400, 500]})

# %%
df3
# Out:
#    x   y    z
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df3.iplot(kind='surface', colorscale='rdylbu')
# Out:
# <div>                            <div id="6ea33273-fdd3-4df1-8a16-15e3f8806b7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Spread: used a lot for stock data
df[['A', 'B']].iplot(kind='spread', fill='tonexty', mode='none', title='Spread')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/cufflinks/plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# /opt/anaconda3/lib/python3.8/site-packages/cufflinks/plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>                            <div id="fd899571-f0ca-4d27-8bb4-b478b6e2636b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Histogram
df['A'].iplot(kind='hist', bins=30, title='Histogram')
# Out:
# <div>                            <div id="3604bab0-42ea-4b43-9983-1cab60d219a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# Bubble
df.iplot(kind='bubble', x='A', y='B', size='C')
# Out:
# <div>                            <div id="ffcd2edb-784a-4dbd-9856-72110ecbb1a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# scatter_matrix
df.scatter_matrix()
# Out:
# <div>                            <div id="aeaf9667-f586-4581-91d3-00090deaa7c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df_1.scatter_matrix()
# Out:
# <div>                            <div id="02df9a53-adca-427e-b10a-1dd99af6515c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
