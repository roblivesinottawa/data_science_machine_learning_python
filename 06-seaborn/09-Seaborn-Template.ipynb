# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # DISTRIBUTION PLOTS

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# distplot
sns.distplot(tips['total_bill'], kde=False, bins=30)

# %%
# jointplots
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')

# %%
# pairplot
sns.pairplot(tips, hue='sex', palette='coolwarm')

# %%
# rugplots
sns.rugplot(tips['total_bill'])

# %%
# kernel density estimation: kde
# https://seaborn.pydata.org/generated/seaborn.kdeplot.html
sns.distplot(tips['total_bill'], kde=False)

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
sns.kdeplot(tips.total_bill, shade=True)

# %% [markdown]
# # CATEGORICAL PLOTS

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# barplot
sns.barplot(x='sex', 
            y='total_bill', 
            data=tips,
            estimator=np.std)

# %%
# countplot
sns.countplot(x='sex', data=tips)

# %%
# boxplot
sns.boxplot(x='day', y='total_bill', data=tips)

# %%
# violin plot
sns.violinplot(x='day', y='total_bill', data=tips)

# %%
# strip plot
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True, hue='sex')
# jitter: randomize the points around the mean

# %%
# swarm plots

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
# swarmplot() is a quick way to show the distribution of a variable.

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips, color='black')

# %%
# factorplot
sns.factorplot(x='day', y='total_bill', data=tips, kind='bar')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# factorplot
sns.factorplot(x='day', y='total_bill', data=tips, kind='violin')

# %%
# factorplot
sns.factorplot(x='day', y='total_bill', data=tips, kind='swarm')

# %% [markdown]
# # Matrix Plots

# %%
tips = sns.load_dataset('tips')
flights = sns.load_dataset("flights")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights['year']
# Out:
# 0      1949
# 1      1949
# 2      1949
# 3      1949
# 4      1949
#        ...
# 139    1960
# 140    1960
# 141    1960
# 142    1960
# 143    1960
# Name: year, Length: 144, dtype: int64

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tc = tips.corr()

# %%
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc, annot=True, cmap='winter_r')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
fp=flights.pivot_table(index="month", columns="year", values="passengers")

# %%
fp
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(fp, cmap=plt.cm.Reds, linecolor='black', linewidths=1)

# %%
# clusteramap: 
sns.clustermap(fp, method='complete', metric='euclidean', cmap='viridis', standard_scale=1, figsize=(10, 10))

# %%
# heatmap: https://seaborn.pydata.org/generated/seaborn.heatmap.html
# a heatmap will display things in the order you put the columns in the dataframe

# clustermap: https://seaborn.pydata.org/generated/seaborn.clustermap.html
# a clustermap will cluster things based on the values in the columns you provide

# %% [markdown]
# # GRIDS

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# pairplot
sns.pairplot(iris)

# %%
sns.PairGrid(iris)

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(data=tips, col="time", row="smoker")
g.map(sns.distplot, "total_bill")

# %%
g = sns.FacetGrid(data=tips, col="time", row="smoker")
g.map(plt.scatter, "total_bill", "tip")

# %% [markdown]
# # REGRESSION PLOTS

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=True, hue='sex')

# %%
sns.lmplot(x='total_bill', 
            y='tip', 
            data=tips, 
            fit_reg=True, 
            hue='sex',
            markers=['o', 'v'],
            scatter_kws={'s': 100})

# %%
sns.lmplot(x='total_bill', 
            y='tip', 
            data=tips, 
            col='day',
            hue="sex",
            aspect=0.6, # ratio between height and width
            height=8)

# %% [markdown]
# #   STYLE AND COLOR

# %%
sns.set_style(None)
sns.countplot(x='sex', data=tips)
# sns.despine(left=True)

# %%
# size and aspect ratio
plt.figure(figsize=(12,3))
sns.countplot(x='sex', data=tips)

# %%
sns.set_context("paper")
sns.countplot(x='sex', data=tips)

# %%
# palettes and colors
# sns.set_style("whitegrid")
sns.lmplot(x="total_bill", y="tip", data=tips, hue='sex', palette="seismic")

# %% [markdown]
# # EXERCISES SEABORN

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# distribution plot, jointplot
sns.jointplot(x='fare', y='age', data=titanic)

# %%
# distribution plot
sns.distplot(titanic.fare, kde=False, color='red', bins=30)

# %%
# boxplot
sns.boxplot(x='class', y='age', data=titanic, palette='rainbow')

# %%
# swarmplot
sns.swarmplot(x='class', y='age', data=titanic, palette='Set3')

# %%
# countplot
sns.countplot(x='sex', data=titanic)

# %%
# heatmap
sns.heatmap(titanic.corr(), cmap="coolwarm")
plt.title("Titanic Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Titanic Correlation Heatmap')

# %%
# FacetGrid
g = sns.FacetGrid(data=titanic, col="sex")
g.map(plt.hist,'age')
