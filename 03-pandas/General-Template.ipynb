# %%
import pandas as pd
import numpy as np

# %%
df_country_info = pd.read_csv('country-info-updated.csv', delimiter=',')

df_country_info
# Out:
#    Unnamed: 0 Country   Population  GDP         Location            Language
# 0           0      US  332,278,200  NaN    North America             English
# 1           1      UK   67,886,004  NaN  Northern Europe             English
# 2           2      ES   47,431,256  NaN           Europe             Spanish
# 3           3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4           4      CA   37,894,799  NaN    North America  English and French

# %%
"""GROUPBY ALLOWS YOU TO GROUP TOGETHER ROWS BASED OFF A COLUMN AND PERFORM AGGREGATE FUNCTIONS ON THEM"""
# Out:
# 'GROUPBY ALLOWS YOU TO GROUP TOGETHER ROWS BASED OFF A COLUMN AND PERFORM AGGREGATE FUNCTIONS ON THEM'

# %%
df_country_info.groupby('Location')

# %%
df_country_info.groupby('Population').mean()
# Out:
#              Unnamed: 0  GDP
# Population
# 125,961,625         3.0  NaN
# 332,278,200         0.0  NaN
# 37,894,799          4.0  NaN
# 47,431,256          2.0  NaN
# 67,886,004          1.0  NaN

# %%
df_country_info.groupby('Population').min()
# Out:
#              Unnamed: 0 Country  GDP         Location            Language
# Population
# 125,961,625           3      JP  NaN   Southeast Asia            Japanese
# 332,278,200           0      US  NaN    North America             English
# 37,894,799            4      CA  NaN    North America  English and French
# 47,431,256            2      ES  NaN           Europe             Spanish
# 67,886,004            1      UK  NaN  Northern Europe             English

# %%
data = {
    'Age': [22, 23, 24, 25, 26],
    'Name': ['Alfred', 'Batman', 'Bender', 'C3PO', 'Data'],
    'Address': ['123 Fake Street', '345 Fake Street', '456 Fake Street', '789 Fake Street', '0'],
    'Phone Number': ['1112223333', '4124234444', '1555666666', '466667777', '1233211212']
}

df = pd.DataFrame(data, columns=['Age', 'Name', 'Address', 'Phone Number'])

# %%
df
# Out:
#    Age    Name          Address Phone Number
# 0   22  Alfred  123 Fake Street   1112223333
# 1   23  Batman  345 Fake Street   4124234444
# 2   24  Bender  456 Fake Street   1555666666
# 3   25    C3PO  789 Fake Street    466667777
# 4   26    Data                0   1233211212

# %%
df.groupby('Age')

# %%
by_comp = df.groupby('Age')

# %%
by_comp

# %%
by_comp.mean()
# Out:
# Empty DataFrame
# Columns: []
# Index: [22, 23, 24, 25, 26]

# %%
by_comp.std()
# Out:
# Empty DataFrame
# Columns: []
# Index: [22, 23, 24, 25, 26]

# %%
by_comp.min()
# Out:
#        Name          Address Phone Number
# Age
# 22   Alfred  123 Fake Street   1112223333
# 23   Batman  345 Fake Street   4124234444
# 24   Bender  456 Fake Street   1555666666
# 25     C3PO  789 Fake Street    466667777
# 26     Data                0   1233211212

# %%
by_comp.describe()
# Out:
#      Name                     Address                               \
#     count unique     top freq   count unique              top freq
# Age
# 22      1      1  Alfred    1       1      1  123 Fake Street    1
# 23      1      1  Batman    1       1      1  345 Fake Street    1
# 24      1      1  Bender    1       1      1  456 Fake Street    1
# 25      1      1    C3PO    1       1      1  789 Fake Street    1
# 26      1      1    Data    1       1      1                0    1
#
#     Phone Number
#            count unique         top freq
# Age
# 22             1      1  1112223333    1
# 23             1      1  4124234444    1
# 24             1      1  1555666666    1
# 25             1      1   466667777    1
# 26             1      1  1233211212    1

# %%
"""MERGING, JOINING AND CONCATENATING"""
# Out:
# 'MERGING, JOINING AND CONCATENATING'

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],  
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],      
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
# concatenation

# %%
pd.concat([df1, df2, df3], axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
import pandas as pd

# %%
pd.concat([df1, df2], axis=0)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1, df2, df3], axis=0)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1, df2, df3], axis=1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left, right
# Out:
# (  key   A   B
#  0  K0  A0  B0
#  1  K1  A1  B1
#  2  K2  A2  B2
#  3  K3  A3  B3,
#    key   C   D
#  0  K0  C0  D0
#  1  K1  C1  D1
#  2  K2  C2  D2
#  3  K3  C3  D3)

# %%
pd.merge(left=left, right=right, how='inner', on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
pd.merge(df1, df2, how='inner', on='A')
# Out:
# Empty DataFrame
# Columns: [A, B_x, C_x, D_x, B_y, C_y, D_y]
# Index: []

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
data = {
    'Age': [22, 23, 24, 25, 26],
    'Name': ['Alfred', 'Batman', 'Bender', 'C3PO', 'Data'],
    'Address': ['123 Fake Street', '345 Fake Street', '456 Fake Street', '789 Fake Street', '0'],
    'Phone Number': ['1112223333', '4124234444', '1555666666', '466667777', '1233211212']
}

df = pd.DataFrame(data, columns=['Age', 'Name', 'Address', 'Phone Number'])

# %%
df
# Out:
#    Age    Name          Address Phone Number
# 0   22  Alfred  123 Fake Street   1112223333
# 1   23  Batman  345 Fake Street   4124234444
# 2   24  Bender  456 Fake Street   1555666666
# 3   25    C3PO  789 Fake Street    466667777
# 4   26    Data                0   1233211212

# %%
"""OPERATIONS"""
# Out:
# 'OPERATIONS'

# %%
df
# Out:
#    Age    Name          Address Phone Number
# 0   22  Alfred  123 Fake Street   1112223333
# 1   23  Batman  345 Fake Street   4124234444
# 2   24  Bender  456 Fake Street   1555666666
# 3   25    C3PO  789 Fake Street    466667777
# 4   26    Data                0   1233211212

# %%
df.head()
# Out:
#    Age    Name          Address Phone Number
# 0   22  Alfred  123 Fake Street   1112223333
# 1   23  Batman  345 Fake Street   4124234444
# 2   24  Bender  456 Fake Street   1555666666
# 3   25    C3PO  789 Fake Street    466667777
# 4   26    Data                0   1233211212

# %%
df['Name'].unique()
# Out:
# array(['Alfred', 'Batman', 'Bender', 'C3PO', 'Data'], dtype=object)

# %%
df['Name'].nunique()
# Out:
# 5

# %%
df_country_info = pd.read_csv('country-info-updated.csv')

# %%
df_country_info
# Out:
#    Unnamed: 0 Country   Population  GDP         Location            Language
# 0           0      US  332,278,200  NaN    North America             English
# 1           1      UK   67,886,004  NaN  Northern Europe             English
# 2           2      ES   47,431,256  NaN           Europe             Spanish
# 3           3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4           4      CA   37,894,799  NaN    North America  English and French

# %%
df_country_info['Country'].unique()
# Out:
# array(['US', 'UK', 'ES', 'JP', 'CA'], dtype=object)

# %%
df_country_info['Country'].nunique()
# Out:
# 5

# %%
df_country_info['Population'].value_counts()
# Out:
# 332,278,200    1
# 67,886,004     1
# 47,431,256     1
# 125,961,625    1
# 37,894,799     1
# Name: Population, dtype: int64

# %%
df_country_info
# Out:
#    Unnamed: 0 Country   Population  GDP         Location            Language
# 0           0      US  332,278,200  NaN    North America             English
# 1           1      UK   67,886,004  NaN  Northern Europe             English
# 2           2      ES   47,431,256  NaN           Europe             Spanish
# 3           3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4           4      CA   37,894,799  NaN    North America  English and French

# %%
df_country_info['Population'][0] < df_country_info['Population'][1]
# Out:
# True

# %%
df_country_info['Population'][1]
# Out:
# '67,886,004'

# %%
df
# Out:
#    Age    Name          Address Phone Number
# 0   22  Alfred  123 Fake Street   1112223333
# 1   23  Batman  345 Fake Street   4124234444
# 2   24  Bender  456 Fake Street   1555666666
# 3   25    C3PO  789 Fake Street    466667777
# 4   26    Data                0   1233211212

# %%
df[(df['Age'] > 18) & (df['Age'] < 25)]
# Out:
#    Age    Name          Address Phone Number
# 0   22  Alfred  123 Fake Street   1112223333
# 1   23  Batman  345 Fake Street   4124234444
# 2   24  Bender  456 Fake Street   1555666666

# %%
df['Age'].apply(lambda x: x*2)
# Out:
# 0    44
# 1    46
# 2    48
# 3    50
# 4    52
# Name: Age, dtype: int64

# %%
df_country_info
# Out:
#    Unnamed: 0 Country   Population  GDP         Location            Language
# 0           0      US  332,278,200  NaN    North America             English
# 1           1      UK   67,886,004  NaN  Northern Europe             English
# 2           2      ES   47,431,256  NaN           Europe             Spanish
# 3           3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4           4      CA   37,894,799  NaN    North America  English and French

# %%
df_country_info.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df_country_info
# Out:
#   Country   Population  GDP         Location            Language
# 0      US  332,278,200  NaN    North America             English
# 1      UK   67,886,004  NaN  Northern Europe             English
# 2      ES   47,431,256  NaN           Europe             Spanish
# 3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4      CA   37,894,799  NaN    North America  English and French

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df_country_info.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.sort_values('Address')
# Out:
#    Age    Name          Address Phone Number
# 4   26    Data                0   1233211212
# 0   22  Alfred  123 Fake Street   1112223333
# 1   23  Batman  345 Fake Street   4124234444
# 2   24  Bender  456 Fake Street   1555666666
# 3   25    C3PO  789 Fake Street    466667777

# %%
df
# Out:
#    Age    Name          Address Phone Number
# 0   22  Alfred  123 Fake Street   1112223333
# 1   23  Batman  345 Fake Street   4124234444
# 2   24  Bender  456 Fake Street   1555666666
# 3   25    C3PO  789 Fake Street    466667777
# 4   26    Data                0   1233211212

# %%
df.sort_values('Name', inplace=True)

# %%
df
# Out:
#    Age    Name          Address Phone Number
# 0   22  Alfred  123 Fake Street   1112223333
# 1   23  Batman  345 Fake Street   4124234444
# 2   24  Bender  456 Fake Street   1555666666
# 3   25    C3PO  789 Fake Street    466667777
# 4   26    Data                0   1233211212

# %%
df = pd.read_csv('country-info-updated.csv')

# %%
df
# Out:
#    Unnamed: 0 Country   Population  GDP         Location            Language
# 0           0      US  332,278,200  NaN    North America             English
# 1           1      UK   67,886,004  NaN  Northern Europe             English
# 2           2      ES   47,431,256  NaN           Europe             Spanish
# 3           3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4           4      CA   37,894,799  NaN    North America  English and French

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#   Country   Population  GDP         Location            Language
# 0      US  332,278,200  NaN    North America             English
# 1      UK   67,886,004  NaN  Northern Europe             English
# 2      ES   47,431,256  NaN           Europe             Spanish
# 3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4      CA   37,894,799  NaN    North America  English and French

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Country, Population, GDP, Location, Language]
# Index: []

# %%
df
# Out:
#   Country   Population  GDP         Location            Language
# 0      US  332,278,200  NaN    North America             English
# 1      UK   67,886,004  NaN  Northern Europe             English
# 2      ES   47,431,256  NaN           Europe             Spanish
# 3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4      CA   37,894,799  NaN    North America  English and French

# %%
df
# Out:
#   Country   Population  GDP         Location            Language
# 0      US  332,278,200  NaN    North America             English
# 1      UK   67,886,004  NaN  Northern Europe             English
# 2      ES   47,431,256  NaN           Europe             Spanish
# 3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4      CA   37,894,799  NaN    North America  English and French

# %%
pwd
# Out:
# '/Users/robsontrajano/Desktop/programming/july_2021/Python_DataScience_MachineLearning_Bootcamp/03-Python-for-Data-Analysis-Pandas'

# %%
pd.read_excel('Excel_Sample.xlsx')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df = pd.read_csv('country-info-updated.csv')

# %%
df
# Out:
#    Unnamed: 0 Country   Population  GDP         Location            Language
# 0           0      US  332,278,200  NaN    North America             English
# 1           1      UK   67,886,004  NaN  Northern Europe             English
# 2           2      ES   47,431,256  NaN           Europe             Spanish
# 3           3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4           4      CA   37,894,799  NaN    North America  English and French

# %%
df.to_csv('country-info-updated.csv', index=False)

# %%
df
# Out:
#    Unnamed: 0 Country   Population  GDP         Location            Language
# 0           0      US  332,278,200  NaN    North America             English
# 1           1      UK   67,886,004  NaN  Northern Europe             English
# 2           2      ES   47,431,256  NaN           Europe             Spanish
# 3           3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4           4      CA   37,894,799  NaN    North America  English and French

# %%
df = pd.read_csv('country-info.csv')

# %%
df
# Out:
#    Unnamed: 0 Country   Population  GDP         Location            Language
# 0           0      US  332,278,200  NaN    North America             English
# 1           1      UK   67,886,004  NaN  Northern Europe             English
# 2           2      ES   47,431,256  NaN           Europe             Spanish
# 3           3      JP  125,961,625  NaN   Southeast Asia            Japanese
# 4           4      CA   37,894,799  NaN    North America  English and French

# %%
pd.read_excel('Excel_Sample.xlsx', sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
"""READING FROM HTML FILE"""
# Out:
# 'READING FROM HTML FILE'

# %%
data = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-c3a4f3471310> in <module>
# ----> 1 data = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1096     io = stringify_path(io)
#    1097
# -> 1098     return _parse(
#    1099         flavor=flavor,
#    1100         io=io,
#
# ...

# %%
"""SQL"""
# Out:
# 'SQL'

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory')

# %%
df.to_sql('data', engine)

# %%
sql_df = pd.read_sql('data', con=engine)

# %%
sql_df
# Out:
#    index  Unnamed: 0 Country   Population  GDP         Location  \
# 0      0           0      US  332,278,200  NaN    North America
# 1      1           1      UK   67,886,004  NaN  Northern Europe
# 2      2           2      ES   47,431,256  NaN           Europe
# 3      3           3      JP  125,961,625  NaN   Southeast Asia
# 4      4           4      CA   37,894,799  NaN    North America
#
#              Language
# 0             English
# 1             English
# 2             Spanish
# 3            Japanese
# 4  English and French
